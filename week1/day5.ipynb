# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
from google import genai
from google.genai import types
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
API_KEY = os.getenv('GEMINI_API_KEY')

# if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
#     print("API key looks good so far")
# else:
#     print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
MODEL = 'gemini-2.5-flash'

client = genai.Client(api_key=API_KEY)

openai = OpenAI()

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
# def get_links(url):
#     website = Website(url)
#     response = openai.chat.completions.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": link_system_prompt},
#             {"role": "user", "content": get_links_user_prompt(website)}
#       ],
#         response_format={"type": "json_object"}
#     )
#     result = response.choices[0].message.content
#     return json.loads(result)


def get_links(url):
    website = Website(url)
    user_prompt = get_links_user_prompt(website)
    

    response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction=link_system_prompt),
    contents= user_prompt
    )
    text = response.text
    cleaned_text = text.replace("```json", "").replace("```", "").strip()
    python_dict = json.loads(cleaned_text)
    return python_dict
    return json.loads(response.text)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  'inference/get-started',
#  '/spaces',
#  '/models',
#  '/zai-org/GLM-4.5',
#  '/Qwen/Qwen3-Coder-480B-A35B-Instruct',
#  '/tencent/HunyuanWorld-1',
#  '/bosonai/higgs-audio-v2-generation-3B-base',
#  '/Qwen/Qwen3-235B-A22B-Thinking-2507',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/zumjoy/Multi-Style_Video-to-Anime_Generator',
#  '/spaces/Qwen/Qwen3-Coder-WebDev',
#  '/spaces/smola/higgs_audio_v2',
#  '/spaces/black-forest-labs/FLUX.1-Kontext-Dev',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/NousResearch/Hermes-3-Dataset',
#  '/datasets/MegaScience/MegaScience',
#  '/datasets/interstellarninja/hermes_reasoning_tool_use',
#  '/datasets/microsoft/rStar-Coder',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'homepage', 'url': 'https://huggingface.co/'},
#   {'type': 'about page', 'url': 'https://huggingface.co/brand'},
#   {'type': 'company profile', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'enterprise solutions', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'careers page', 'url': 'https://huggingface.co/join'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'resources page', 'url': 'https://huggingface.co/learn'},
#   {'type': 'blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company profile',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'homepage', 'url': 'https://huggingface.co/'}, {'type': 'models overview', 'url': 'https://huggingface.co/models'}, {'type': 'datasets overview', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces overview', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation', 'url': 'https://huggingface.co/docs'}, {'type': 'enterprise solutions', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing', 'url': 'https://huggingface.co/pricing'}, {'type': 'changelog', 'url': 'https://huggingface.co/changelog'}, {'type': 'API endpoints', 'url': 'https://endpoints.huggingface.co'}, {'type': 'chat product', 'url': 'https://huggingface.co/chat'}, {'type': 'company profile', 'url': 'https://huggingface.co/huggingface'}, {'type': 'brand guidelines', 'url': 'https://huggingface.co/brand'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'educational resources', 'url': 'https://huggingface.co/learn'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'github profile', 'url': 'https://github.com/huggingface'}, {'type': 'twitter profile', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin profile', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'discord community', 'url': 'https://huggingface.co/join/discord'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# zai-org/GLM-4.5
# Updated
# 2 days ago
# •
# 3.93k
# •
# 716
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# 7 days ago
# •
# 17.4k
# •
# 920
# tencent/HunyuanWorld-1
# Updated
# 2 days ago
# •
# 6.83k
# •
# 447
# bosonai/higgs-audio-v2-generation-3B-base
# Updated
# 2 days ago
# •
# 111k
# •
# 454
# Qwen/Qwen3-235B-A22B-Thinking-2507
# Updated
# about 8 hours ago
# •
# 4.08k
# •
# 242
# Browse 1M+ models
# Spaces
# Running
# 11.2k
# 11.2k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 236
# 236
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# Running
# 248
# 248
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Running
# on
# Zero
# 237
# 237
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# Running
# on
# Zero
# MCP
# 1.16k
# 1.16k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 32.7k
# •
# 8.51k
# NousResearch/Hermes-3-Dataset
# Updated
# 19 days ago
# •
# 6.28k
# •
# 264
# MegaScience/MegaScience
# Updated
# 7 days ago
# •
# 3.03k
# •
# 56
# interstellarninja/hermes_reasoning_tool_use
# Updated
# 8 days ago
# •
# 1.27k
# •
# 73
# microsoft/rStar-Coder
# Updated
# 11 days ago
# •
# 10.5k
# •
# 159
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 776 models
# •
# 3.71k followers
# AI at Meta
# Enterprise
# company
# •
# 2.2k models
# •
# 6.99k followers
# Amazon
# company
# •
# 20 models
# •
# 3.32k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 22.3k followers
# Intel
# company
# •
# 233 models
# •
# 2.8k followers
# Microsoft
# company
# •
# 418 models
# •
# 13.9k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 171 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,672
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,000
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,371
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,804
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,945
# Fast tokenizers optimized for research & production
# TRL
# 14,818
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,249
# State-of-the-art ML running directly in your browser
# smolagents
# 21,684
# Smol library to build great agents in Python
# PEFT
# 19,173
# Parameter-efficient finetuning for large language models
# Datasets
# 20,438
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,375
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,980
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# homepage
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# zai-org/GLM-4.5
# Updated
# 2 days ago
# •
# 3.93k
# •
# 716
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# 7 days ago
# •
# 17.4k
# •
# 920
# tencent/HunyuanWorld-1
# Updated
# 2 days ago
# •
# 6.83k
# •
# 447
# bosonai/higgs-audio-v2-generation-3B-base
# Updated
# 2 days ago
# •
# 111k
# •
# 454
# Qwen/Qwen3-235B-A22B-Thinking-2507
# Updated
# about 8 hours ago
# •
# 4.08k
# •
# 242
# Browse 1M+ models
# Spaces
# Running
# 11.2k
# 11.2k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 236
# 236
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# Running
# 248
# 248
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Running
# on
# Zero
# 237
# 237
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# Running
# on
# Zero
# MCP
# 1.16k
# 1.16k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 32.7k
# •
# 8.51k
# NousResearch/Hermes-3-Dataset
# Updated
# 19 days ago
# •
# 6.28k
# •
# 264
# MegaScience/MegaScience
# Updated
# 7 days ago
# •
# 3.03k
# •
# 56
# interstellarninja/hermes_reasoning_tool_use
# Updated
# 8 days ago
# •
# 1.27k
# •
# 73
# microsoft/rStar-Coder
# Updated
# 11 days ago
# •
# 10.5k
# •
# 159
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 776 models
# •
# 3.71k followers
# AI at Meta
# Enterprise
# company
# •
# 2.2k models
# •
# 6.99k followers
# Amazon
# company
# •
# 20 models
# •
# 3.32k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 22.3k followers
# Intel
# company
# •
# 233 models
# •
# 2.8k followers
# Microsoft
# company
# •
# 418 models
# •
# 13.9k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 171 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,672
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,000
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,371
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,804
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,945
# Fast tokenizers optimized for research & production
# TRL
# 14,818
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,249
# State-of-the-art ML running directly in your browser
# smolagents
# 21,684
# Smol library to build great agents in Python
# PEFT
# 19,173
# Parameter-efficient finetuning for large language models
# Datasets
# 20,438
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,375
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,980
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# models overview
# Webpage Title:
# Models - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Models filters
# Main
# Tasks
# Libraries
# Languages
# Licenses
# Other
# Tasks
# Text Generation
# Any-to-Any
# Image-Text-to-Text
# Image-to-Text
# Image-to-Image
# Text-to-Image
# Text-to-Video
# Text-to-Speech
# + 42
# Parameters
# Reset Parameters
# < 1B
# 6B
# 12B
# 32B
# 128B
# > 500B
# < 1B
# > 500B
# Libraries
# PyTorch
# google-tensorflow
# TensorFlow
# JAX
# Transformers
# Diffusers
# Safetensors
# ONNX
# GGUF
# Transformers.js
# MLX
# Keras
# + 41
# Apps
# vLLM
# TGI
# llama.cpp
# MLX LM
# LM Studio
# Ollama
# Jan
# + 12
# Inference Providers
# Novita
# Cerebras
# Nebius AI
# Featherless AI
# Together AI
# Fireworks
# Groq
# Hyperbolic
# + 6
# Apply filters
# Models
# Full-text search
# Add filters
# Sort:
# 		Trending
# zai-org/GLM-4.5
# Text Generation
# •
# 358B
# •
# Updated
# 2 days ago
# •
# 3.93k
# •
# •
# 716
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Text Generation
# •
# 480B
# •
# Updated
# 7 days ago
# •
# 17.4k
# •
# •
# 920
# tencent/HunyuanWorld-1
# Image-to-3D
# •
# Updated
# 2 days ago
# •
# 6.83k
# •
# 447
# bosonai/higgs-audio-v2-generation-3B-base
# Text-to-Speech
# •
# 6B
# •
# Updated
# 2 days ago
# •
# 111k
# •
# 454
# Qwen/Qwen3-235B-A22B-Thinking-2507
# Text Generation
# •
# 235B
# •
# Updated
# about 8 hours ago
# •
# 4.08k
# •
# •
# 242
# Qwen/Qwen3-30B-A3B-Instruct-2507
# Text Generation
# •
# 31B
# •
# Updated
# about 8 hours ago
# •
# 1.49k
# •
# 240
# zai-org/GLM-4.5-Air
# Text Generation
# •
# 110B
# •
# Updated
# 2 days ago
# •
# 1.34k
# •
# 231
# Chain-GPT/Solidity-LLM
# Text Generation
# •
# 3B
# •
# Updated
# 7 days ago
# •
# 1.48k
# •
# 369
# moonshotai/Kimi-K2-Instruct
# Text Generation
# •
# Updated
# 3 days ago
# •
# 315k
# •
# •
# 1.93k
# Wan-AI/Wan2.2-TI2V-5B
# Text-to-Video
# •
# Updated
# 2 days ago
# •
# 7.32k
# •
# 163
# internlm/Intern-S1
# Image-Text-to-Text
# •
# 241B
# •
# Updated
# 3 days ago
# •
# 3.58k
# •
# 151
# black-forest-labs/FLUX.1-Kontext-dev
# Image-to-Image
# •
# Updated
# Jun 27
# •
# 325k
# •
# •
# 1.93k
# Qwen/Qwen3-235B-A22B-Instruct-2507
# Text Generation
# •
# 235B
# •
# Updated
# about 8 hours ago
# •
# 20.8k
# •
# •
# 558
# Wan-AI/Wan2.2-T2V-A14B
# Text-to-Video
# •
# Updated
# 2 days ago
# •
# •
# 123
# unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF
# 31B
# •
# Updated
# about 19 hours ago
# •
# 18.6k
# •
# 121
# nvidia/Llama-3_3-Nemotron-Super-49B-v1_5
# Text Generation
# •
# 50B
# •
# Updated
# about 7 hours ago
# •
# 2.25k
# •
# 117
# Tesslate/UIGEN-X-32B-0727
# Text Generation
# •
# 0.0B
# •
# Updated
# 3 days ago
# •
# 249
# •
# 107
# Wan-AI/Wan2.2-I2V-A14B
# Image-to-Video
# •
# Updated
# 3 days ago
# •
# •
# 99
# neta-art/Neta-Lumina
# Text-to-Image
# •
# Updated
# 5 days ago
# •
# 15.5k
# •
# 236
# Comfy-Org/Wan_2.2_ComfyUI_Repackaged
# Updated
# 2 days ago
# •
# 91
# Qwen/Qwen3-30B-A3B-Thinking-2507
# Text Generation
# •
# 31B
# •
# Updated
# about 8 hours ago
# •
# 2
# •
# 77
# ByteDance-Seed/Seed-X-PPO-7B
# Translation
# •
# Updated
# 3 days ago
# •
# 19.8k
# •
# 190
# mistralai/Magistral-Small-2507
# 24B
# •
# Updated
# 2 days ago
# •
# 1.34k
# •
# 73
# Kijai/WanVideo_comfy
# 16B
# •
# Updated
# about 17 hours ago
# •
# 8.27k
# •
# 1.03k
# black-forest-labs/FLUX.1-dev
# Text-to-Image
# •
# Updated
# Jun 27
# •
# 1.54M
# •
# •
# 11k
# PowerInfer/SmallThinker-21BA3B-Instruct
# Text Generation
# •
# 22B
# •
# Updated
# about 22 hours ago
# •
# 253
# •
# 68
# mistralai/Voxtral-Mini-3B-2507
# 5B
# •
# Updated
# 2 days ago
# •
# 153k
# •
# 490
# unsloth/Qwen3-Coder-480B-A35B-Instruct-GGUF
# Text Generation
# •
# 480B
# •
# Updated
# about 2 hours ago
# •
# 67.9k
# •
# 128
# Skywork/Skywork-UniPic-1.5B
# Text-to-Image
# •
# Updated
# 1 day ago
# •
# 55
# unsloth/Qwen3-235B-A22B-Thinking-2507-GGUF
# 235B
# •
# Updated
# 5 days ago
# •
# 43.4k
# •
# 54
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# datasets overview
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Datasets filters
# Main
# Tasks
# Libraries
# Languages
# Licenses
# Other
# Modalities
# 3D
# Audio
# Document
# Geospatial
# Image
# Tabular
# Text
# Time-series
# Video
# Size
# 			(rows)
# Reset Size
# < 1K
# > 1T
# Format
# json
# csv
# parquet
# imagefolder
# soundfolder
# webdataset
# text
# arrow
# Apply filters
# Datasets
# 464,079
# Full-text search
# Add filters
# Sort:
# 		Trending
# fka/awesome-chatgpt-prompts
# Viewer
# •
# Updated
# Jan 6
# •
# 203
# •
# 32.7k
# •
# 8.51k
# NousResearch/Hermes-3-Dataset
# Viewer
# •
# Updated
# 19 days ago
# •
# 959k
# •
# 6.28k
# •
# 264
# MegaScience/MegaScience
# Viewer
# •
# Updated
# 7 days ago
# •
# 1.25M
# •
# 3.03k
# •
# 56
# interstellarninja/hermes_reasoning_tool_use
# Viewer
# •
# Updated
# 8 days ago
# •
# 51k
# •
# 1.27k
# •
# 73
# microsoft/rStar-Coder
# Viewer
# •
# Updated
# 11 days ago
# •
# 1.86M
# •
# 10.5k
# •
# 159
# zai-org/CC-Bench-trajectories
# Viewer
# •
# Updated
# 2 days ago
# •
# 208
# •
# 2.21k
# •
# 24
# multimodal-reasoning-lab/Zebra-CoT
# Viewer
# •
# Updated
# 5 days ago
# •
# 160k
# •
# 5.43k
# •
# 33
# nvidia/Nemotron-Post-Training-Dataset-v1
# Viewer
# •
# Updated
# about 6 hours ago
# •
# 25.7M
# •
# 140
# •
# 19
# UCSC-VLAA/GPT-Image-Edit-1.5M
# Viewer
# •
# Updated
# about 7 hours ago
# •
# 2.78M
# •
# 4.68k
# •
# 19
# common-pile/caselaw_access_project
# Viewer
# •
# Updated
# Jun 6
# •
# 5.52M
# •
# 5.45k
# •
# 175
# deepvk/NonverbalTTS
# Viewer
# •
# Updated
# 8 days ago
# •
# 6.26k
# •
# 755
# •
# 29
# allenai/CoSyn-400K
# Viewer
# •
# Updated
# Feb 28
# •
# 408k
# •
# 2.18k
# •
# 32
# nvidia/Llama-Nemotron-Post-Training-Dataset
# Viewer
# •
# Updated
# May 8
# •
# 3.91M
# •
# 7.5k
# •
# 545
# open-thoughts/OpenThoughts3-1.2M
# Viewer
# •
# Updated
# Jun 9
# •
# 1.2M
# •
# 12.3k
# •
# 146
# atalaydenknalbant/rawg-games-dataset
# Viewer
# •
# Updated
# 9 days ago
# •
# 890k
# •
# 381
# •
# 25
# atalaydenknalbant/MathCaptcha10k
# Viewer
# •
# Updated
# 24 days ago
# •
# 21.8k
# •
# 1.48k
# •
# 17
# HuggingFaceM4/the_cauldron
# Viewer
# •
# Updated
# May 6, 2024
# •
# 1.88M
# •
# 29.5k
# •
# 483
# atalaydenknalbant/Kinetics-700
# Viewer
# •
# Updated
# 4 days ago
# •
# 635k
# •
# 191
# •
# 11
# HuggingFaceFW/fineweb
# Viewer
# •
# Updated
# 19 days ago
# •
# 52.5B
# •
# 722k
# •
# 2.27k
# FreedomIntelligence/medical-o1-reasoning-SFT
# Viewer
# •
# Updated
# Apr 22
# •
# 90.1k
# •
# 8.67k
# •
# 800
# XenArcAI/MathX-5M
# Viewer
# •
# Updated
# 5 days ago
# •
# 4.32M
# •
# 5.42k
# •
# 51
# facebook/seamless-interaction
# Updated
# 16 days ago
# •
# 158k
# •
# 124
# theaidealab/workflows
# Updated
# 1 day ago
# •
# 4.62k
# •
# 13
# spatialverse/InteriorGS
# Updated
# 6 days ago
# •
# 231
# •
# 9
# iitolstykh/NHR-Edit
# Viewer
# •
# Updated
# 7 days ago
# •
# 4.6k
# •
# 36.7k
# •
# 20
# cais/hle
# Viewer
# •
# Updated
# May 20
# •
# 2.5k
# •
# 13.3k
# •
# 439
# Rapidata/text-2-video-human-preferences-genmo-mochi-1
# Viewer
# •
# Updated
# 2 days ago
# •
# 1.1k
# •
# 80
# •
# 8
# moondream/synthcat
# Viewer
# •
# Updated
# 3 days ago
# •
# 2M
# •
# 436
# •
# 7
# open-r1/OpenR1-Math-220k
# Viewer
# •
# Updated
# Feb 18
# •
# 450k
# •
# 28k
# •
# 623
# cais/mmlu
# Viewer
# •
# Updated
# Mar 8, 2024
# •
# 231k
# •
# 257k
# •
# 517
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# spaces overview
# Webpage Title:
# Spaces - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Spaces
# ·
# The AI App Directory
# New Space
# Get PRO
# Learn more
# Image Generation
# Video Generation
# Text Generation
# Language Translation
# Speech Synthesis
# 3D Modeling
# Object Detection
# Text Analysis
# Image Editing
# Code Generation
# Question Answering
# Data Visualization
# Voice Cloning
# Background Removal
# Image Upscaling
# OCR
# Document Analysis
# Visual QA
# Image Captioning
# Chatbots
# Sentiment Analysis
# Text Summarization
# Music Generation
# Medical Imaging
# Financial Analysis
# Game AI
# Model Benchmarking
# Fine Tuning Tools
# Dataset Creation
# Pose Estimation
# Face Recognition
# Anomaly Detection
# Recommendation Systems
# Character Animation
# Style Transfer
# Image
# Spaces of the week
# 28 Jul 2025
# Filters
# (0)
# Sort:
# 		Relevance
# Running
# on
# Zero
# 237
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# smola
# 8 days ago
# Running
# 248
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Qwen
# about 14 hours ago
# Running
# 236
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# zumjoy
# 7 days ago
# Running
# on
# L4
# 93
# OmniSVG 3B
# 📈
# OmniSVG-Demo-Page
# OmniSVG
# 8 days ago
# Running
# 33
# Voxtral WebGPU
# 🐱
# State-of-the-art audio transcription in your browser
# webml-community
# 6 days ago
# Running
# 36
# Music Arena Leaderboard
# 🎵
# AI Music Arena & Leaderboard (Suno, udio, Google, Meta, +)
# ArtificialAnalysis
# 7 days ago
# Running
# 10
# Drag And Drop LLMs
# 💬
# Display and download evaluation data for tasks
# Jerrylz
# 9 days ago
# Running
# on
# Zero
# MCP
# 78
# Wan 2.2 5B
# 🚀
# Generate high-quality videos from text prompts and images
# Wan-AI
# 1 day ago
# All running apps, trending first
# Running
# 11.2k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# enzostvs
# 5 days ago
# Running
# 236
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# zumjoy
# 7 days ago
# Running
# 248
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Qwen
# about 14 hours ago
# Running
# on
# Zero
# 237
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# smola
# 8 days ago
# Running
# on
# Zero
# MCP
# 1.16k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# black-forest-labs
# 28 days ago
# Running
# 2.44k
# Anycoder
# 🏢
# Generate modern web applications with code
# akhaliq
# about 9 hours ago
# Running
# on
# Zero
# 878
# Hunyuan3D-2.1
# 👻
# Image-to-3D Generation
# tencent
# Jun 20
# Running
# 197
# LLM Embeddings Explained: A Visual and Intuitive Guide
# 🚀
# How Language Models Turn Text into Meaning, From Traditional
# hesamation
# Mar 28
# Running
# on
# Zero
# MCP
# 1.36k
# Wan2.1 Fast
# 🎥
# Generate animated videos from images
# multimodalart
# 23 days ago
# Running
# 85
# Qwen3 MT Demo
# 🏃
# Translate text between multiple languages
# Qwen
# 6 days ago
# Running
# on
# Zero
# MCP
# 78
# Wan 2.2 5B
# 🚀
# Generate high-quality videos from text prompts and images
# Wan-AI
# 1 day ago
# Running
# on
# Zero
# 8.96k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# black-forest-labs
# Apr 16
# Running
# 187
# UltimaX Intelligence
# ⚡
# Premium AI | Tools | Code Interpreter | Web Generator | etc
# umint
# about 13 hours ago
# Running
# 1.07k
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# NihalGazi
# Jun 29
# Running
# on
# Zero
# 93
# MegaTTS 3 Voice Cloning
# 🎤
# MegaTTS 3 but with voice cloning!
# mrfakename
# 6 days ago
# Running
# on
# CPU Upgrade
# 9.42k
# Kolors Virtual Try-On
# 👕
# Try on clothes virtually by uploading person and garment images
# Kwai-Kolors
# Sep 18, 2024
# Running
# on
# Zero
# 98
# ObjectClear
# 🪄
# Remove objects from images interactively
# jixin0101
# 23 days ago
# Running
# 54
# GLM 4.5 Demo (API)
# 🏃
# Generate text-based responses through conversational chat
# zai-org
# 2 days ago
# Running
# on
# L4
# 93
# OmniSVG 3B
# 📈
# OmniSVG-Demo-Page
# OmniSVG
# 8 days ago
# Running
# on
# Zero
# MCP
# 102
# Addit
# ⚡
# Add objects to images using text prompts
# nvidia
# 6 days ago
# Running
# on
# Zero
# MCP
# 1.03k
# LTX Video Fast
# 🎥
# ultra-fast video model, LTX 0.9.8 13B distilled
# Lightricks
# 13 days ago
# Running
# 43
# OnePoseviaGen
# 💻
# Estimate 3D object pose from a single image
# ZhengGeng
# 1 day ago
# Running
# 1.26k
# Sparc3D
# 🏃
# Next-Gen High-Resolution 3D Model Generation
# ilcve21
# Jun 28
# Running
# on
# Zero
# MCP
# 1.31k
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# ResembleAI
# Jun 25
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# documentation
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentation
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Deploying on AWS
# Train/deploy models from Hugging Face to AWS with DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Microsoft Azure
# Deploy Hugging Face models on Microsoft Azure
# Core ML Libraries
# Transformers
# State-of-the-art AI models for PyTorch
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# LeRobot
# Making AI for Robotics more accessible with end-to-end learning
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# enterprise solutions
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Team & Enterprise Hub
# Scale your organization with the world’s leading AI platform
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Inference Providers
# Enable organization billing for Inference Providers, monitor usage with analytics, and manage spending limits.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 22.3k followers
# Shopify
# Enterprise
# company
# •
# 502 followers
# AMD
# Enterprise
# company
# •
# 159 models
# •
# 1.71k followers
# JetBrains
# Team
# company
# •
# 11 models
# •
# 644 followers
# Together
# Team
# company
# •
# 33 models
# •
# 655 followers
# Xsolla
# Enterprise
# company
# •
# 155 followers
# Toyota Research Institute
# Team
# company
# •
# 10 models
# •
# 133 followers
# TNG Technology Consulting GmbH
# Team
# company
# •
# 5 models
# •
# 261 followers
# FuriosaAI
# Team
# company
# •
# 14 models
# •
# 96 followers
# Technology Innovation Institute
# Team
# company
# •
# 104 models
# •
# 1.53k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 171 followers
# MiniMax
# Team
# company
# •
# 10 models
# •
# 1.61k followers
# Novo Nordisk R&ED
# Team
# company
# •
# 53 followers
# Lightricks
# Team
# company
# •
# 18 models
# •
# 1.19k followers
# NVIDIA
# Enterprise
# +
# company
# •
# 449 models
# •
# 33.3k followers
# AI at Meta
# Enterprise
# company
# •
# 2.2k models
# •
# 6.99k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 255 followers
# Arm
# Enterprise
# company
# •
# 243 followers
# Qwen
# Team
# company
# •
# 331 models
# •
# 40.9k followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 304 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 166 followers
# Jusbrasil
# Team
# company
# •
# 100 followers
# creditkarma
# Enterprise
# company
# •
# 77 followers
# Aledade Inc
# Enterprise
# +
# company
# •
# 72 followers
# HyperCLOVA X
# Team
# company
# •
# 4 models
# •
# 470 followers
# HiddenLayer
# Team
# company
# •
# 1 model
# •
# 76 followers
# LinkedIn
# Enterprise
# company
# •
# 70 followers
# Twelve Labs
# Team
# company
# •
# 52 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 54.7k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 307 followers
# Snowflake
# Enterprise
# company
# •
# 24 models
# •
# 578 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# ServiceNow
# Enterprise
# company
# •
# 2 models
# •
# 532 followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 124 followers
# Fidelity Investments
# Enterprise
# company
# •
# 154 followers
# IBM Granite
# Team
# company
# •
# 125 models
# •
# 2.12k followers
# BAIDU
# Team
# company
# •
# 25 models
# •
# 917 followers
# H2O.ai
# Team
# company
# •
# 71 models
# •
# 440 followers
# Chegg Inc
# Enterprise
# company
# •
# 89 followers
# Roblox Corporation
# Enterprise
# company
# •
# 5 models
# •
# 262 followers
# Liquid AI
# Team
# company
# •
# 8 models
# •
# 428 followers
# BCG X
# Team
# company
# •
# 41 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Give your personal account or your organization the most advanced platform to build AI.
# PRO
# PRO Account
# Boost your personal HF experience
# Subscribe for
# $9
# per month
# Get PRO
# 10× private storage capacity
# 20× included inference credits
# 8× ZeroGPU quota and highest queue priority
# Spaces Dev Mode & ZeroGPU Spaces hosting
# Publish blog articles on your HF profile
# Dataset Viewer for private datasets
# Show your support with a Pro badge
# Team
# Instant setup for growing teams
# Subscribe for
# $20
# per user per month
# Get Team (via credit card)
# SSO and SAML support
# Choose data location with Storage Regions
# Detailed action reviews with Audit Logs
# Granular access control via Resource Groups
# Repository usage Analytics
# Set auth policies and default repository visibility
# Centralized token control and approvals
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# All organization members get ZeroGPU and Inference Providers PRO benefits
# Enterprise
# Custom onboarding and enterprise features
# Starting at
# $50
# per user per month
# Contact Sales
# All benefits from the Team plan
# Managed billing with annual commitments
# Legal and Compliance processes
# Personalized support
# Need support to adopt the HF Hub in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $2.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# ZeroGPU
# dynamic
# dynamic
# Nvidia H200
# 70 GB
# FREE
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# aws
# Intel Sapphire Rapids (overcommit)
# 16
# 32GB
# $0.01
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $2.50
# 2
# 160GB
# $5.00
# 4
# 320GB
# $10.00
# 8
# 640GB
# $20.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# Inference Providers
# : Get 20× included inference credits
# ZeroGPU
# : Get 8× usage quota and highest priority in queues
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Dataset Viewer
# : Activate and use it on private datasets
# Blog Articles
# : Publish articles on your HF profile
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# changelog
# Webpage Title:
# Changelog - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Changelog
# Keep track of latest changes on the Hugging Face Hub
# Jul 30, 25
# Upvote
# 31
# +26
# Jul 30, 25
# Introducing HF Jobs: Run scalable compute jobs on Hugging Face
# Hugging Face Jobs lets you effortlessly run compute tasks on our infrastructure—from simple scripts to large-scale workloads—with a simple CLI. Whether you need CPUs, or high-end GPUs, Jobs provides instant access to the hardware you need, billed by the second.
# Quick Start Examples:
# Run Python code directly:
# hf
# jobs
# run python:3.12 python -c
# "print('Hello from the cloud!')"
# Use GPUs without any setup:
# hf
# jobs
# run --flavor=t4-small ubuntu nvidia-smi
# Jul 28, 25
# Upvote
# 30
# +25
# Jul 28, 25
# Trending Papers
# The Daily Papers page now includes
# Trending Papers
# , showcasing the most popular and impactful research papers from the community, along with their corresponding code implementations on GitHub. Trending Papers are ranked based on recent GitHub star activity.
# Jul 25, 25
# Upvote
# 47
# +42
# Jul 25, 25
# Introducing a better Hugging Face CLI
# We’ve renamed
# huggingface-cli
# to
# hf
# and overhauled the command structure for speed and clarity. The new CLI now uses the format
# hf <resource> <action>
# , so commands like
# hf auth login
# ,
# hf repo create
# , or
# hf download Qwen/Qwen3-0.6B
# are now consistent and intuitive.
# Migration is easy, the old CLI still works and will gently point you to the new commands.
# You can learn more by reading the full announcement in this
# blog article
# .
# Jul 23, 25
# Upvote
# 28
# +23
# Jul 23, 25
# JSON Support in the Dataset Viewer
# You can now view JSON cells directly in the Dataset Viewer, making it far easier to expand nested structures, copy useful snippets, and understand your data.
# This feature is particularly useful for tool calling datasets like
# interstellarninja/hermes_reasoning_tool_use
# and
# Salesforce/APIGen-MT-5k
# .
# Jul 18, 25
# Upvote
# 71
# +66
# Jul 18, 25
# Inference Providers now fully support OpenAI-compatible API
# Our Inference Providers service now fully supports the OpenAI-compatible API, making it easy to integrate with existing workflows. Plus, you can now specify the provider name directly in the model path for greater flexibility.
# This means you can effortlessly switch between different inference providers while using the familiar OpenAI client—just point to
# router.huggingface.co/v1
# and include the provider in the model name.
# This update simplifies integration while maintaining full compatibility with OpenAI's SDK. Try it now with supported providers like novita, groq, together, and more!
# Previous
# 1
# 2
# 3
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# API endpoints
# Webpage Title:
# Inference Endpoints by Hugging Face
# Webpage Contents:
# Inference
# Endpoints
# Catalog
# Log In
# Machine Learning At Your Service
# by
# Hugging Face
# Easily deploy Transformers, Diffusers or any model on dedicated, fully managed
# 				infrastructure. Keep your costs low with our secure, compliant and flexible production
# 				solution.
# Log In
# Learn More
# No Hugging Face account ?
# Sign up
# !
# One-click inference deployment
# Import your favorite model from the Hugging Face hub or browse our catalog of hand-picked, ready-to-deploy models !
# meta-llama /
# Llama-3.1-70B-Instruct
# Text Generation
# TGI
# Accelerated Text Generation Inference
# GPU
# 4x Nvidia L40S
# $
# 8.3
# Qwen /
# Qwen2.5-Coder-7B-Instruct
# Text Generation
# TGI
# Accelerated Text Generation Inference
# GPU
# 1x Nvidia L40S
# $
# 1.8
# openai /
# whisper-large-v3-turbo
# Automatic Speech Recognition
# GPU
# 1x Nvidia L4
# $
# 0.8
# mixedbread-ai /
# mxbai-embed-large-v1
# Sentence Embeddings
# TEI
# Accelerated Text Embeddings Inference
# GPU
# 1x Nvidia L4
# $
# 0.8
# black-forest-labs /
# FLUX.1-schnell
# Text-to-Image
# GPU
# 1x Nvidia L40S
# $
# 1.8
# Browse Catalog
# Hub Models
# Customer Stories
# Learn how leading AI teams use Inference Endpoints to deploy their models
# Endpoints for
# Music
# Musixmatch is the world’s leading music data company
# Use Case
# Custom text embeddings generation pipeline
# Models Deployed
# Distilbert-base-uncased-finetuned-sst-2-english
# facebook/wav2vec2-base-960h
# Custom model based on sentence transformers
# The coolest thing was how easy it was to define a complete custom interface from the model to the inference process. It just took us a couple of hours to adapt our code, and have a functioning and totally custom endpoint.
# Andrea Boscarino
# Data Scientist at Musixmatch
# Endpoints for
# Health
# Phamily improves patient health with intelligent care management
# Use Case
# HIPAA-compliant secure endpoints for text classification
# Models Deployed
# Custom model based on text-classification (MPNET)
# Custom model based on text-classification (BERT)
# It took off a week's worth of developer time. Thanks to Inference Endpoints, we now basically spend all of our time on R&D, not fiddling with AWS. If you haven't already built a robust, performant, fault tolerant system for inference, then it's pretty much a no brainer.
# Bryce Harlan
# Senior Software Engineer at Phamily
# Endpoints for
# Search
# Pinecone is the vector database for intelligent search
# Use Case
# Autoscaling endpoints for fast embeddings generation
# Models Deployed
# Different sentence transformers and embedding models
# We were able to choose an off the shelf model that's very common for our customers to get started with and set it so that it can be configured to handle over 100 requests per second just with a few button clicks. With the release of the Hugging Face Inference Endpoints, we believe there's a new standard for how easy it can be to go build your first vector embedding based solution, whether it be semantic search or question answering system.
# Gareth Jones
# Senior Product Manager at Pinecone
# Endpoints for
# Videos
# Waymark is a AI-powered video creator
# Use Case
# Multi-modal endpoints for embeddings, audio and image generation
# Models Deployed
# sentence-transformers/all-mpnet-base-v2
# google/vit-base-patch16-224-in21k
# Custom model based on florentgbelidji/blip_captioning
# You're bringing the potential time delta between - I've never seen anything that could do this before - to - I could have it on infrastructure ready to support an existing product - down to potentially less than a day.
# Nathan Labenz
# Founder at Waymark
# Pricing
# Choose a plan that fits your needs
# Self-Serve
# Pay as you go when using Inference Endpoints
# Pay for what you use, per minute
# Starting as low as $0.06/hour
# Billed monthly
# Email support
# See Pricing
# Enterprise
# Get a custom quote and premium support
# Lower marginal costs based on volume
# Uptime guarantees
# Custom annual contracts
# Dedicated support, SLAs
# Request a Quote
#
#
#
# chat product
# Webpage Title:
# HuggingChat
# Webpage Contents:
# We are cooking something new,
# please stay tuned...
# Privacy
#         Policy
#
#
#
# company profile
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 51,391
# AI & ML interests
# The AI community building the future.
# Recent Activity
# sayakpaul
# updated
# a dataset
# about 6 hours ago
# huggingface/diffusers-metadata
# stevhliu
# new
# activity
# about 6 hours ago
# huggingface/documentation-images:
# Upload gpt_neox_japanese-attn-mask.png
# badaoui
# authored
# a paper
# 22 days ago
# FAROS: Fair Graph Generation via Attribute Switching Mechanisms
# View all activity
# Articles
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# 8 days ago
# •
# 29
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 48
# Team members
# 211
# +177
# +164
# +143
# +133
# +113
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.7M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 805k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.08M
# •
# •
# 801
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.7M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 805k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.08M
# •
# •
# 801
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 15
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# Jun 27
# pinned
# Running
# on
# CPU Upgrade
# 15
# Hugging Face Fast
# 🏎
# Test Hugging Face bandwidth
# huggingface
# Jun 12
# pinned
# Running
# 96
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# on
# CPU Upgrade
# 191
# Inference Playground
# 🔋
# Set theme for Hugging Face Playground
# huggingface
# 9 days ago
# Running
# on
# CPU Upgrade
# 18
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# Jun 18
# Running
# 449
# AI Deadlines
# ⚡
# Manage project deadlines efficiently
# huggingface
# Jun 8
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 3.38k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 18
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.03k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 17
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 2.6k
# •
# 10
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 166
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 2.42k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 16
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 54.1k
# •
# •
# 82
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# about 6 hours ago
# •
# 72
# •
# 544
# •
# 7
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 6 hours ago
# •
# 55
# •
# 2.73M
# •
# 77
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 2 days ago
# •
# 1.79k
# •
# 1.14k
# •
# 26
# huggingface/policy-docs
# Viewer
# •
# Updated
# 11 days ago
# •
# 26
# •
# 2.48k
# •
# 13
# huggingface/badges
# Viewer
# •
# Updated
# 13 days ago
# •
# 1
# •
# 416k
# •
# 45
# huggingface/cats-image
# Viewer
# •
# Updated
# Jun 20
# •
# 1
# •
# 11.5k
# •
# 2
# huggingface/label-files
# Updated
# Jun 12
# •
# 2.19k
# •
# 19
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 43
# •
# 1
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 49
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 85
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# brand guidelines
# Webpage Title:
# Brand assets - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face · Brand assets
# HF Logos
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# .svg
# .png
# .ai
# HF Colors
# #FFD21E
# #FF9D00
# #6B7280
# HF Bio
# Hugging Face is the collaboration platform for the machine learning community.
#
# The Hugging Face Hub works as a central place where anyone can share, explore, discover, and experiment with open-source ML. HF empowers the next generation of machine learning engineers, scientists, and end users to learn, collaborate and share their work to build an open and ethical AI future together.
#
# With the fast-growing community, some of the most used open-source ML libraries and tools, and a talented science team exploring the edge of tech, Hugging Face is at the heart of the AI revolution.
# Copy to clipboard
# HF Universe
# Find other assets available for use from the Hugging Face brand universe
# here
# .
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# educational resources
# Webpage Title:
# Hugging Face - Learn
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Learn
# LLM Course
# This course will teach you about large language models using libraries from the HF ecosystem
# MCP Course
# This course will teach you about Model Context Protocol
# Agents Course
# Learn to build and deploy your own AI agents
# Deep RL Course
# This course will teach you about deep reinforcement learning using libraries from the HF ecosystem
# Community Computer Vision Course
# This course will teach you about computer vision ML using libraries and models from the HF ecosystem
# Audio Course
# Learn to apply transformers to audio data using libraries from the HF ecosystem
# Open-Source AI Cookbook
# A collection of open-source-powered notebooks by AI builders, for AI builders
# ML for Games Course
# This course will teach you about integrating AI models your game and using AI tools in your game development workflow
# Diffusion Course
# Learn about diffusion models & how to use them with diffusers
# ML for 3D Course
# Learn about 3D ML with libraries from the HF ecosystem
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Introducing Trackio: A Lightweight Experiment Tracking Library from Hugging Face
# By
# abidlabs
# July 29, 2025
# •
# 87
# Community Articles
# view all
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 14 days ago
# •
# 126
# LLMGameHub: How We Won the Gradio Agents & MCP Hackathon 2025
# By
# kikikita
# and 1 other
# •
# 2 days ago
# •
# 14
# AI Companionship: Why We Need to Evaluate How AI Systems Handle Emotional Bonds
# By
# giadap
# and 2 others
# •
# 9 days ago
# •
# 12
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 104
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 9 days ago
# •
# 19
# ...
# 1
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 148k
# 29.8k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 30k
# 6.2k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.4k
# 2.9k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 19.2k
# 2k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 9k
# 1.2k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 3k
# 567
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# Makefile
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 337 repositories
# yourbench
# Public
# Forked from
# sumukshashidhar/yourbench
# 🤗 Benchmark Large Language Models Reliably On Your Data
# huggingface/yourbench’s past year of commit activity
# Python
# 366
# Apache-2.0
# 36
# 16
# 3
# Updated
# Jul 30, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 143
# Apache-2.0
# 14
# 10
# 13
# Updated
# Jul 30, 2025
# transformers.js-examples
# Public
# A collection of 🤗 Transformers.js demos and example applications
# huggingface/transformers.js-examples’s past year of commit activity
# JavaScript
# 1,687
# Apache-2.0
# 195
# 12
# 8
# Updated
# Jul 30, 2025
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 147,672
# Apache-2.0
# 29,843
# 1,064
# (2 issues need help)
# 827
# Updated
# Jul 30, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,980
# Apache-2.0
# 1,163
# 87
# (4 issues need help)
# 14
# Updated
# Jul 30, 2025
# transformers.js
# Public
# State-of-the-art Machine Learning for the web. Run 🤗 Transformers directly in your browser, with no need for a server!
# huggingface/transformers.js’s past year of commit activity
# JavaScript
# 14,249
# Apache-2.0
# 968
# 346
# (3 issues need help)
# 62
# Updated
# Jul 30, 2025
# responses.js
# Public
# A lightweight express.js server implementing OpenAI’s Responses API, built on top of Chat Completions, powered by Hugging Face Inference Providers.
# huggingface/responses.js’s past year of commit activity
# TypeScript
# 147
# MIT
# 9
# 0
# 0
# Updated
# Jul 30, 2025
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 191
# Apache-2.0
# 265
# 16
# (1 issue needs help)
# 31
# Updated
# Jul 30, 2025
# gpu-fryer
# Public
# Where GPUs get cooked 👩‍🍳🔥
# huggingface/gpu-fryer’s past year of commit activity
# Rust
# 237
# Apache-2.0
# 12
# 1
# 1
# Updated
# Jul 30, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 30,000
# Apache-2.0
# 6,154
# 533
# (12 issues need help)
# 207
# Updated
# Jul 30, 2025
# View all repositories
# People
# View all
# Sponsoring
# Top languages
# Python
# Jupyter Notebook
# TypeScript
# Rust
# MDX
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# GitHub Sponsor
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# twitter profile
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# linkedin profile
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 591 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at Hugging Face 🤗 | Making AI work for libraries, archives, and their communities
# 8h
# Report this post
# I just ran batch inference on a 30B parameter LLM across 4 GPUs with a single Python command!
#
# The secret? Modern AI infrastructure where everyone handles their specialty:
#
# 📦 UV (by
# Astral
# ) handles dependencies via uv scripts
# 🖥️
# Hugging Face
# Jobs handles GPU orchestration
# 🧠
# Qwen AI
# team handles the model (Qwen3-30B-A3B-Instruct-2507)
# ⚡
# vLLM
# handles efficient batched inference
#
# I'm very excited about using uv scripts as a nice way of packaging fairly simple but useful ML tasks in a somewhat reproducible way. This combined with Jobs opens up some nice oppertunities for making pipelines that require different types of compute.
#
# Technical deep dive and code examples:
# https://lnkd.in/e5BEBU95
# Efficient batch inference for LLMs with vLLM + UV Scripts on HF Jobs
# danielvanstrien.xyz
# 127
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 10h
# Report this post
# 🚀 Introducing JSVibes - vibe testing open models for simple, yet useful web development tasks
#
#
# - A list of 50 web micro-apps you can play with
# - Implementations by kimi k2 and qwen3-code, side-by-side
# - Judged by kimi k2
#
# The Qwen3-code win rate is 88%. Personally, I don't always agree; you'd better play with the apps yourself!
#
# Built with
# Hugging Face
# AISheets
# …more
# 52
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Alan Chhabra
# Executive Vice President, WW Partners @ Cerebras
# 1d
# Report this post
# Cerebras Systems
# is very proud to be offering Qwen3-235B 2507 with our strategic partner ,
# Hugging Face
# !
# https://lnkd.in/dDBcqHpc
# Thank you
# Clem Delangue 🤗
# Vaibhav Srivastav
# and
# Julien Chaumond
# for the partnership!
# Qwen/Qwen3-235B-A22B-Instruct-2507 · Hugging Face
# huggingface.co
# 122
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,917 followers
# 1d
# Report this post
# Don't use any ML tracking solution for your training runs before reading this!
# 🔥 Technical Report:
# https://lnkd.in/gqhguKbP
# …more
# 35
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,917 followers
# 1d
# Edited
# Report this post
# 😍 A multi-agent platform where users CREATE & PLAY AI-generated games with dynamic stories, visuals & music — built with
# Gradio
# ,
# LangChain
# 's
# LangGraph AI
# ,
# Google Gemini
# , Google Lyria, &
# Redis
# .
#
# Team won first place at the Gradio Agents & MCP Hackathon 2025!
# Published on
# Hugging Face
# Blog:
# https://lnkd.in/gWpV5k88
# 89
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at Hugging Face 🤗 | Making AI work for libraries, archives, and their communities
# 2d
# Report this post
# HF Jobs just launched - and here's how to get started in seconds! 🚀
#
# I extracted text from thousands of classified UFO documents with one command:
#
# ```
# hf jobs uv run --flavor l4x1 \
# https://lnkd.in/e3JyYPsD
# \
#  davanstrien/ufo-ColPali davanstrien/ufo-ocr
# ```
#
# From aged government documents with typewriter text, stamps, and handwriting → clean, searchable markdown. All powered by Nanonets-OCR-s, a state-of-the-art vision-language model that handles LaTeX, tables, forms, and complex layouts. Running on cloud GPUs with zero setup.
#
# This is the power of HF Jobs + uv Scripts:
# - No local GPU needed
# - No dependency management
# - Scripts are self-contained with inline metadata
# - Pay only for compute time used
#
# The uv Scripts organization (
# huggingface.co/uv-scripts
# ) is building a collection of ready-to-run ML tools:
# - VLM-based OCR for any documents
# - Text classification with structured outputs
# - PDF to dataset conversion
# - High-performance vLLM inference
#
# Each script works instantly - just `hf jobs uv run [script] [args]` and you're processing data on A100s.
#
# Big thanks to
# Charlie Marsh
# and the
# Astral
# team for building uv - this amazing tooling makes it all possible!
#
# What repetitive ML task would save you time if it were a one-command script? Drop a comment below - would love to hear what the community needs!
# 228
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 2d
# Report this post
# Serving LLMs? Turns out 𝐩𝐲𝐭𝐡𝐨𝐧 𝐢𝐬 𝐀𝐋𝐋 𝐲𝐨𝐮 𝐧𝐞𝐞𝐝!
# Hugging Face
# transformers now includes a built-in LLM inference server. Pair it with
# Gradio
# , and you can spin up a fully local, private chat UI with any LLM hosted on the Hugging Face Hub – all in just two lines of code!
# …more
# 705
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,917 followers
# 2d
# Edited
# Report this post
# 📢 Integrate your business backends into any MCP-compatible LLM!!
#
# 👉 👉 Transform OpenAPI Specs to MCP servers in One Line!
# Earlier: Manually map API endpoints to MCP tools. Time-consuming + error-prone.
# Now: Automated process with Gradio👇 Single line implementation!
#
# Key features:
# * Browse the UI and filter the endpoints that matter
# * Host your MCP server for free on
# Hugging Face
# * Complete No code solution 🤯
# …more
# 131
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,917 followers
# 5d
# Edited
# Report this post
# 📢WILD! You'll soon be able to build IMMERSIVE apps in Python🤯 stay tuned for more ..
# …more
# 89
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,917 followers
# 5d
# Report this post
# Vibe editor built into your local experience!🤩
#
# Coming soon, stay tuned fam!
# …more
# 114
# 7 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# discord community
# Webpage Title:
# Hugging Face
# Webpage Contents:

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co/'}, {'type': 'enterprise solutions', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing', 'url': 'https://huggingface.co/pricing'}, {'type': 'brand information', 'url': 'https://huggingface.co/brand'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'learning resources', 'url': 'https://huggingface.co/learn'}, {'type': 'documentation', 'url': 'https://huggingface.co/docs'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nGet started with Inference in seconds 🚀\nReachy Mini: The Open Robot for AI Builders\nWelcome Cohere on the Hub 🔥\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nzai-org/GLM-4.5\nUpdated\n2 days ago\n•\n3.93k\n•\n716\nQwen/Qwen3-Coder-480B-A35B-Instruct\nUpdated\n7 days ago\n•\n17.4k\n•\n920\ntencent/HunyuanWorld-1\nUpdated\n2 days ago\n•\n6.83k\n•\n447\nbosonai/higgs-audio-v2-generation-3B-base\nUpdated\n2 days ago\n•\n111k\n•\n454\nQwen/Qwen3-235B-A22B-Thinking-2507\nUpdated\nabout 8 hours ago\n•\n4.08k\n•\n242\nBrowse 1M+ models\nSpaces\nRunning\n11.2k\n11.2k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\n236\n236\nMulti-Style Video-to-Anime Generator\n📊\nTransfer your videos with different AnimeStyles & havefun!\nRunning\n248\n248\nQwen3 Coder WebDev\n🌍\nGenerate web application code from descriptions\nRunning\non\nZero\n237\n237\nHiggs Audio Demo\n🎤\nHiggs Audio Demo\nRunning\non\nZero\nMCP\n1.16k\n1.16k\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n32.7k\n•\n8.51k\nNousResearch/Hermes-3-Dataset\nUpdated\n19 days ago\n•\n6.28k\n•\n264\nMegaScience/MegaScience\nUpdated\n7 days ago\n•\n3.03k\n•\n56\ninterstellarninja/hermes_reasoning_tool_use\nUpdated\n8 days ago\n•\n1.27k\n•\n73\nmicrosoft/rStar-Coder\nUpdated\n11 days ago\n•\n10.5k\n•\n159\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n776 models\n•\n3.71k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.2k models\n•\n6.99k followers\nAmazon\ncompany\n•\n20 models\n•\n3.32k followers\nGoogle\nEnterprise\ncompany\n•\n1.04k models\n•\n22.3k followers\nIntel\ncompany\n•\n233 models\n•\n2.8k followers\nMicrosoft\ncompany\n•\n418 models\n•\n13.9k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n171 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n317 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n147,672\nState-of-the-art AI models for PyTorch\nDiffusers\n30,000\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,371\nSafe way to store/distribute neural network weights\nHub Python Library\n2,804\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,945\nFast tokenizers optimized for research & production\nTRL\n14,818\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,249\nState-of-the-art ML running directly in your browser\nsmolagents\n21, ...

# %%
# def create_brochure(company_name, url):
#     response = openai.chat.completions.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": system_prompt},
#             {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
#           ],
#     )
#     result = response.choices[0].message.content
#     display(Markdown(result))

def create_brochure(company_name, url):
    user_prompt = get_brochure_user_prompt(company_name, url)

    response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction=link_system_prompt),
    contents= user_prompt
    )
    result = response.text
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co/'}, {'type': 'offering page', 'url': 'https://huggingface.co/models'}, {'type': 'offering page', 'url': 'https://huggingface.co/datasets'}, {'type': 'offering page', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'offering page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'product page', 'url': 'https://huggingface.co/chat'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'about page', 'url': 'https://huggingface.co/brand'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'learning page', 'url': 'https://huggingface.co/learn'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}]}
# ```json
# {
#     "links": [
#         {"type": "about page", "url": "https://huggingface.co/about"},
#         {"type": "careers page", "url": "https://huggingface.co/jobs"},
#         {"type": "enterprise page", "url": "https://huggingface.co/enterprise"},
#         {"type": "pricing page", "url": "https://huggingface.co/pricing"}
#     ]
# }
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    # stream = openai.chat.completions.create(
    #     model=MODEL,
    #     messages=[
    #         {"role": "system", "content": system_prompt},
    #         {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
    #       ],
    #     stream=True
    # )
    user_prompt = get_brochure_user_prompt(company_name, url)

    response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction=link_system_prompt),
    contents= user_prompt
    )
    stream = response.text

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'homepage', 'url': 'https://huggingface.co'}, {'type': 'brand information', 'url': 'https://huggingface.co/brand'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'models overview', 'url': 'https://huggingface.co/models'}, {'type': 'datasets overview', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces overview', 'url': 'https://huggingface.co/spaces'}, {'type': 'enterprise solutions', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'product offering', 'url': 'https://endpoints.huggingface.co'}, {'type': 'product offering', 'url': 'https://huggingface.co/chat'}, {'type': 'documentation', 'url': 'https://huggingface.co/docs'}, {'type': 'learning resources', 'url': 'https://huggingface.co/learn'}, {'type': 'blog/news', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'community discord', 'url': 'https://huggingface.co/join/discord'}]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 stream_brochure("HuggingFace", "https://huggingface.co")
#
# Cell In[19], line 23, in stream_brochure(company_name, url)
#      21 display_handle = display(Markdown(""), display_id=True)
#      22 for chunk in stream:
# ---> 23     response += chunk.choices[0].delta.content or ''
#      24     response = response.replace("```","").replace("markdown", "")
#      25     update_display(Markdown(response), display_id=display_handle.display_id)
#
# AttributeError: 'str' object has no attribute 'choices'

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

# stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
